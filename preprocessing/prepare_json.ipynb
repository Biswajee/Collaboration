# %%
import pandas as pd
import json

# %%
df = pd.read_table('pantheon.tsv', sep='\t')
df.head()
# Out:
#    en_curid             name  numlangs         birthcity birthstate  \
# 0       307  Abraham Lincoln       131       Hodgenville         KY
# 1       308        Aristotle       152          Stageira        NaN
# 2       339         Ayn Rand        55  Saint Petersburg        NaN
# 3       595     Andre Agassi        69         Las Vegas         NV
# 4       628    Aldous Huxley        62         Godalming        NaN
#
#       countryName countryCode countryCode3        LAT         LON    ...      \
# 0   UNITED STATES          US          USA  37.571111  -85.738611    ...
# 1          Greece          GR          GRC  40.333333   23.500000    ...
# 2          Russia          RU          RUS  59.950000   30.300000    ...
# 3   UNITED STATES          US          USA  36.121514 -115.173851    ...
# 4  UNITED KINGDOM          GB          GBR  51.185000   -0.610000    ...
#
#       occupation           industry        domain TotalPageViews     L_star  \
# ...

# %%
variables = ['en_curid', 'name', 'countryName', 'occupation']

# %%
df[variables].head()
# Out:
#    en_curid             name     countryName     occupation
# 0       307  Abraham Lincoln   UNITED STATES     POLITICIAN
# 1       308        Aristotle          Greece    PHILOSOPHER
# 2       339         Ayn Rand          Russia         WRITER
# 3       595     Andre Agassi   UNITED STATES  TENNIS PLAYER
# 4       628    Aldous Huxley  UNITED KINGDOM         WRITER

# %%
x = df[variables]
x.rename(columns = {'en_curid': 'id', 'countryName': 'description', 'occupation': 'category_type'}, inplace=True)
x.head()
# Out:
# G:\Anaconda3\lib\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
#     id             name     description  category_type
# 0  307  Abraham Lincoln   UNITED STATES     POLITICIAN
# 1  308        Aristotle          Greece    PHILOSOPHER
# 2  339         Ayn Rand          Russia         WRITER
# 3  595     Andre Agassi   UNITED STATES  TENNIS PLAYER
# 4  628    Aldous Huxley  UNITED KINGDOM         WRITER

# %%
data = []
# open a json file and save json data
with open('data.json', 'w') as outfile:
    for i in x.index:
        data.append(json.loads(x.loc[i].to_json()))
    json.dump(data, outfile)
